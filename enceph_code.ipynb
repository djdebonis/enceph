# %%
# imports modules required for reading & analyzing data
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 10,5
plt.rcParams['font.size'] = 16

# %%
# creates 'quick code' function to read the .csv file 
enceph_data = pd.read_csv('brain_size.csv', delimiter=',')

# %%
enceph_data
# Out:
#                             type  time (mya)  endocranial_volume (cc^3)  \
# 0      sahelanthropus_tchadensis       7.000                        360
# 1      sahelanthropus_tchadensis       6.000                        380
# 2      sahelanthropus_tchadensis       6.000                        320
# 3      sahelanthropus_tchadensis       6.000                        320
# 4      sahelanthropus_tchadensis       7.000                        380
# 5      sahelanthropus_tchadensis       6.000                        350
# 6      sahelanthropus_tchadensis       7.000                        370
# 7           ardipithecus_ramidus       4.400                        350
# 8           ardipithecus_ramidus       4.400                        350
# 9     australopithecus_anamensis       3.800                        370
# 10    australopithecus_anamensis       3.800                        365
# 11          ardipithecus_ramidus       4.400                        300
# ...

# %%
time = enceph_data['time (mya)']
brain_size = enceph_data['endocranial_volume (cc^3)']

plt.scatter(time, brain_size)
#plt.xlim(8, -1)  # decreasing time
plt.show()
